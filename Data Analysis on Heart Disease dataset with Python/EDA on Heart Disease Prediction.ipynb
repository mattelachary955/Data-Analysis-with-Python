# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
df = pd.read_csv("/kaggle/input/heart-failure-prediction/heart.csv")
df.head()
# Out:
# /kaggle/input/heart-failure-prediction/heart.csv
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
sns.displot(df["Age"], kde = True)

# %%
sns.distplot(df["Age"], kde = True, hist = True)
# Out:
# /tmp/ipykernel_42/862803984.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], kde = True, hist = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Age"], kde = True, hist = True, rug = True)
# Out:
# /tmp/ipykernel_42/2768730592.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"], kde = True, hist = True, rug = True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df["Cholesterol"], kde = True, hist = True)
# Out:
# /tmp/ipykernel_42/3281748070.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Cholesterol"], kde = True, hist = True)
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
sns.distplot(df["RestingBP"])
# Out:
# /tmp/ipykernel_42/2807266475.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["RestingBP"])
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
plt.figure(figsize = (12,6))
ax = sns.countplot(x = df["Age"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.title("Number of people of different ages")
plt.show()

# %%
df.groupby("HeartDisease").count()["Age"].plot(kind = "bar", title = "Number of People with Heart Disease or Not", ylabel = "Count")
# Out:
# <Axes: title={'center': 'Number of People with Heart Disease or Not'}, xlabel='HeartDisease', ylabel='Count'>

# %%
df.groupby("HeartDisease").size().plot(kind = "pie", autopct = "%.2f", title = "Percentage of people with HeartDisease or not")
# Out:
# <Axes: title={'center': 'Percentage of people with HeartDisease or not'}>

# %%
df.groupby("Age").count()
# Out:
#      Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  \
# Age
# 28     1              1          1            1          1           1      1
# 29     3              3          3            3          3           3      3
# 30     1              1          1            1          1           1      1
# 31     2              2          2            2          2           2      2
# 32     5              5          5            5          5           5      5
# 33     2              2          2            2          2           2      2
# 34     7              7          7            7          7           7      7
# 35    11             11         11           11         11          11     11
# 36     6              6          6            6          6           6      6
# 37    11             11         11           11         11          11     11
# 38    16             16         16           16         16          16     16
# ...

# %%
plt.figure(figsize = (12,6))
ax = sns.countplot(x = "Age",hue = "HeartDisease", data = df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
plt.title("Number of people with Heart Disease or Not on age basis")
plt.show()

# %%
df.groupby("Sex").count()["Age"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Age'>

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.groupby("ChestPainType")["ChestPainType"].value_counts().plot(kind = "pie", autopct = "%.2f", title = "Percentage of ChestPain types among people")
# Out:
# <Axes: title={'center': 'Percentage of ChestPain types among people'}, ylabel='count'>

# %%
df.groupby("ChestPainType")["ChestPainType"].value_counts().plot(kind = "bar", title = "Number of people with ChestPain types")
# Out:
# <Axes: title={'center': 'Number of people with ChestPain types'}, xlabel='ChestPainType'>

# %%
df["RestingECG"]
# Out:
# 0      Normal
# 1      Normal
# 2          ST
# 3      Normal
# 4      Normal
#         ...
# 913    Normal
# 914    Normal
# 915    Normal
# 916       LVH
# 917    Normal
# Name: RestingECG, Length: 918, dtype: object

# %%
df["RestingECG"].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
df["RestingECG"].value_counts().plot(kind = "bar", title = "Number of People with electrocardiogram results")
# Out:
# <Axes: title={'center': 'Number of People with electrocardiogram results'}, xlabel='RestingECG'>

# %%
sns.violinplot(data = df, x = "HeartDisease", y = "Sex" )
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %% [markdown]
# # From above Violin part, it is clear that Male is prone to Heart Disease than Female

# %%
sns.violinplot(data = df, x = "HeartDisease", y = "Age" )
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# # From above Violin part, it is clear that People between 55 to 65 are prone to HeartDisease

# %% [markdown]
# # Correlation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.loc[:, ["Age","RestingBP","Cholesterol","FastingBS", "MaxHR", "Oldpeak", "HeartDisease"]].corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.loc[:, ["Age","RestingBP","Cholesterol","FastingBS", "MaxHR", "Oldpeak", "HeartDisease"]].corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x = "Age", y = "MaxHR", data =  df, kind = "reg")

# %% [markdown]
# # From above Plot, Heart rate decreases as age increases because of negative correlation

# %%
sns.pairplot(df)

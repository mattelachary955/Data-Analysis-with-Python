# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.drop("Product_Category_3", axis = 1, inplace = True)
df.drop("Product_Category_2", axis = 1, inplace = True)

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# # Column Analysis

# %%
for i in df.columns:
    print(df[i].head(2))
    print(i, ":", df[i].nunique())
# Out:
# 0    1000001
# 1    1000001
# Name: User_ID, dtype: int64
# User_ID : 5891
# 0    P00069042
# 1    P00248942
# Name: Product_ID, dtype: object
# Product_ID : 3623
# 0    F
# 1    F
# Name: Gender, dtype: object
# Gender : 2
# 0    0-17
# 1    0-17
# Name: Age, dtype: object
# Age : 7
# 0    10
# 1    10
# Name: Occupation, dtype: int64
# Occupation : 21
# 0    A
# 1    A
# Name: City_Category, dtype: object
# City_Category : 3
# 0    2
# 1    2
# Name: Stay_In_Current_City_Years, dtype: object
# Stay_In_Current_City_Years : 5
# 0    0
# 1    0
# Name: Marital_Status, dtype: int64
# Marital_Status : 2
# 0    3
# 1    1
# Name: Product_Category_1, dtype: int64
# Product_Category_1 : 18
# 0     8370
# 1    15200
# Name: Purchase, dtype: int64
# Purchase : 17959

# %%
df.groupby("Gender").sum()["Purchase"].plot(kind = "bar")
# Out:
# <ipython-input-8-9d76a6a506bb>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Gender").sum()["Purchase"].plot(kind = "bar")
# <Axes: xlabel='Gender'>

# %%
df.groupby("Gender").sum()["Purchase"]
# Out:
# <ipython-input-9-abcc08863e5a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Gender").sum()["Purchase"]
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
df.groupby("Age")["Purchase"].size().plot(kind = "pie", autopct = "%.2f", title = "Purchase Percentage based on age", figsize = (6,6))
# Out:
# <Axes: title={'center': 'Purchase Percentage based on age'}, ylabel='Purchase'>

# %%
df.groupby("Age")["Purchase"].sum().plot(kind = "bar", title = "Total Purchase based on Ages")
# Out:
# <Axes: title={'center': 'Total Purchase based on Ages'}, xlabel='Age'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df["Product_ID"].value_counts()
# Out:
# P00265242    1858
# P00110742    1591
# P00025442    1586
# P00112142    1539
# P00057642    1430
#              ...
# P00203242       1
# P00203642       1
# P00364342       1
# P00051742       1
# P00091742       1
# Name: Product_ID, Length: 3623, dtype: int64

# %%
lst = []
for i in df["Age"].unique():
    lst.append([i, df[df["Age"] == i]["Product_ID"].nunique()])
df_age_prod = pd.DataFrame(lst, columns = ["Age", "Products"])

# %%
df_age_prod
# Out:
#      Age  Products
# 0   0-17      2300
# 1    55+      2573
# 2  26-35      3419
# 3  46-50      3099
# 4  51-55      2877
# 5  36-45      3318
# 6  18-25      3213

# %%
plt.title("Number of Products Purchased based on Ages")
sns.barplot(data = df_age_prod, x = "Age", y="Products")
plt.ylabel("Number of Products")
# Out:
# Text(0, 0.5, 'Number of Products')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("Marital_Status").size().plot(kind = "pie", title = "Percentage of People who are married and unmarried", autopct = "%.2f")
# Out:
# <Axes: title={'center': 'Percentage of People who are married and unmarried'}>

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
sns.set_theme(rc = {'figure.figsize' : (12,6)})
sns.barplot(data = df, x = "Age",y="Purchase", hue = "Gender")
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %%
sns.set_theme(rc = {'figure.figsize' : (12,6)})
sns.countplot(data = df, x = "Age", hue = "Gender")
plt.title("Number of Male and Female of Certain ages")
# Out:
# Text(0.5, 1.0, 'Number of Male and Female of Certain ages')

# %%
sns.set_theme(rc = {'figure.figsize' : (12,6)})
sns.countplot(data = df, x = "Gender", hue = "Age")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = df["City_Category"])
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sns.countplot(data = df, x = "City_Category", hue = "Gender")
plt.title("Number of People living in different cities")
# Out:
# Text(0.5, 1.0, 'Number of People living in different cities')

# %%
sns.barplot(x = "City_Category", y = "Purchase",hue = "Gender", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='Purchase'>

# %%
df.groupby("City_Category").count()["Gender"]
# Out:
# City_Category
# A    144638
# B    226493
# C    166446
# Name: Gender, dtype: int64

# %%
sns.countplot(x = "City_Category", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("Marital_Status").sum()
# Out:
# <ipython-input-112-9fdbe949d41c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Marital_Status").sum()
#                      User_ID  Occupation  Product_Category_1    Purchase
# Marital_Status
# 0               318759372904     2526251             1662649  2966289500
# 1               220425975246     1818828             1184115  2051378878

# %%
df.groupby("Marital_Status").sum()["Purchase"].plot(kind = "bar")
# Out:
# <ipython-input-114-4b7486419da0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Marital_Status").sum()["Purchase"].plot(kind = "bar")
# <Axes: xlabel='Marital_Status'>

# %%
sns.countplot(data = df, x = "City_Category", hue = "Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.groupby("Stay_In_Current_City_Years").count()["Marital_Status"]
# Out:
# Stay_In_Current_City_Years
# 0      72725
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# Name: Marital_Status, dtype: int64

# %%
sns.countplot(x = "Stay_In_Current_City_Years", data = df, hue = "Marital_Status" )
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Gender").count()["Stay_In_Current_City_Years"]
# Out:
# Gender
# F    132197
# M    405380
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
sns.countplot(x = "Stay_In_Current_City_Years", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years").sum()["Purchase"]
# Out:
# <ipython-input-130-3beb973a1818>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Stay_In_Current_City_Years").sum()["Purchase"]
# Stay_In_Current_City_Years
# 0      672505429
# 1     1763243917
# 2      934676626
# 3      872531130
# 4+     774711276
# Name: Purchase, dtype: int64

# %%
df.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind = "bar")
# Out:
# <ipython-input-129-d04c99552729>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Stay_In_Current_City_Years").sum()["Purchase"].plot(kind = "bar")
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby("Stay_In_Current_City_Years").mean()["Purchase"].plot(kind = "bar", ylabel = "Count")
# Out:
# <ipython-input-133-bbf1055d609a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Stay_In_Current_City_Years").mean()["Purchase"].plot(kind = "bar", ylabel = "Count")
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='Count'>

# %%
sns.countplot(x = "Occupation", data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Occupation").count()["Purchase"].sort_values(ascending = False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").sum()["Purchase"].sort_values(ascending = False).plot(kind = "bar")
# Out:
# <ipython-input-141-fa00726a2f72>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Occupation").sum()["Purchase"].sort_values(ascending = False).plot(kind = "bar")
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").mean()["Purchase"].sort_values(ascending = False).plot(kind = "bar")
# Out:
# <ipython-input-143-63d797df047c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Occupation").mean()["Purchase"].sort_values(ascending = False).plot(kind = "bar")
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").mean()["Purchase"].sort_values(ascending  = False)
# Out:
# <ipython-input-146-bf011db474f8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Occupation").mean()["Purchase"].sort_values(ascending  = False)
# Occupation
# 17    9906.378997
# 12    9883.052460
# 15    9866.239925
# 8     9576.508530
# 14    9568.536426
# 7     9502.175276
# 16    9457.133118
# 13    9424.449391
# 5     9388.848978
# 6     9336.378620
# 11    9299.467190
# 4     9279.026742
# 3     9238.077277
# 18    9233.671418
# 0     9186.946726
# 10    9052.836410
# 2     9025.938982
# 1     9017.703095
# 20    8881.099514
# 19    8754.249162
# 9     8714.335934
# Name: Purchase, dtype: float64

# %%
sns.countplot(x = "Occupation", hue = "Gender", data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = "Occupation", hue = "Marital_Status", data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby("Product_Category_1").count()["Purchase"]
# Out:
# Product_Category_1
# 1     138353
# 2      23499
# 3      19849
# 4      11567
# 5     148592
# 6      20164
# 7       3668
# 8     112132
# 9        404
# 10      5032
# 11     23960
# 12      3875
# 13      5440
# 14      1500
# 15      6203
# 16      9697
# 17       567
# 18      3075
# Name: Purchase, dtype: int64

# %%
df.groupby("Product_Category_1").count()
# Out:
#                     User_ID  Product_ID  Gender     Age  Occupation  \
# Product_Category_1
# 1                    138353      138353  138353  138353      138353
# 2                     23499       23499   23499   23499       23499
# 3                     19849       19849   19849   19849       19849
# 4                     11567       11567   11567   11567       11567
# 5                    148592      148592  148592  148592      148592
# 6                     20164       20164   20164   20164       20164
# 7                      3668        3668    3668    3668        3668
# 8                    112132      112132  112132  112132      112132
# 9                       404         404     404     404         404
# 10                     5032        5032    5032    5032        5032
# 11                    23960       23960   23960   23960       23960
# 12                     3875        3875    3875    3875        3875
# ...

# %%
df.groupby("Product_Category_1").count()["Purchase"].sort_values().plot(kind = "bar", title = "Number of Purchases of each Product Category")
# Out:
# <Axes: title={'center': 'Number of Purchases of each Product Category'}, xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind = "bar", title = "Purchase of each Category")
# Out:
# <ipython-input-165-10408035fcae>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_Category_1").sum()["Purchase"].sort_values().plot(kind = "bar", title = "Purchase of each Category")
# <Axes: title={'center': 'Purchase of each Category'}, xlabel='Product_Category_1'>

# %%
df.groupby("Product_Category_1").mean()["Purchase"].sort_values().plot(kind = "bar", title = "Average amount of each Category")
# Out:
# <ipython-input-166-bfcf9616328b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_Category_1").mean()["Purchase"].sort_values().plot(kind = "bar", title = "Average amount of each Category")
# <Axes: title={'center': 'Average amount of each Category'}, xlabel='Product_Category_1'>

# %%
df.groupby("Product_ID").count().head()
# Out:
#             User_ID  Gender   Age  Occupation  City_Category  \
# Product_ID
# P00000142      1130    1130  1130        1130           1130
# P00000242       371     371   371         371            371
# P00000342       238     238   238         238            238
# P00000442        92      92    92          92             92
# P00000542       146     146   146         146            146
#
#             Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# Product_ID
# P00000142                         1130            1130                1130
# P00000242                          371             371                 371
# P00000342                          238             238                 238
# P00000442                           92              92                  92
# P00000542                          146             146                 146
#
#             Purchase
# Product_ID
# P00000142       1130
# P00000242        371
# P00000342        238
# ...

# %%
df.groupby("Product_ID")["Purchase"].count().nlargest(15)
# Out:
# Product_ID
# P00265242    1858
# P00110742    1591
# P00025442    1586
# P00112142    1539
# P00057642    1430
# P00184942    1424
# P00046742    1417
# P00058042    1396
# P00059442    1384
# P00145042    1384
# P00237542    1374
# P00255842    1354
# P00117942    1346
# P00110942    1336
# P00010742    1331
# Name: Purchase, dtype: int64

# %%
df.groupby("Product_ID").sum()["Purchase"]
# Out:
# <ipython-input-184-c3405c4eaebe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_ID").sum()
#                User_ID  Occupation  Marital_Status  Product_Category_1  \
# Product_ID
# P00000142   1133430069        9009             424                3390
# P00000242    372133315        2813             137                 742
# P00000342    238642834        1873              95                1190
# P00000442     92284575         630              38                 460
# P00000542    146474434        1057              45                 730
# ...                ...         ...             ...                 ...
# P0099442     196579444        1570              56                1176
# P0099642      13035661         131               5                 104
# ...

# %%
df.groupby("Product_ID").sum()["Purchase"].nlargest(15).plot( kind = "bar", title = "Purchased amount of Product_ID of top 15 Purchases")
# Out:
# <ipython-input-189-868cefaabc82>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_ID").sum()["Purchase"].nlargest(15).plot( kind = "bar", title = "Purchased amount of Product_ID of top 15 Purchases")
# <Axes: title={'center': 'Purchased amount of Product_ID of top 15 Purchases'}, xlabel='Product_ID'>

# %%
df.groupby("Product_ID").mean()["Purchase"].nlargest(15).plot( kind = "bar", title = "Average amount of Product_ID of top 15 Purchases")
# Out:
# <ipython-input-190-04354cd20a70>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("Product_ID").mean()["Purchase"].nlargest(15).plot( kind = "bar", title = "Average amount of Product_ID of top 15 Purchases")
# <Axes: title={'center': 'Average amount of Product_ID of top 15 Purchases'}, xlabel='Product_ID'>

# %%
df.groupby("Product_ID").count()["Purchase"].nlargest(15).plot( kind = "bar", title = "Number of times that Product_ID item is Purchased of top 15 Purchases")
# Out:
# <Axes: title={'center': 'Number of times that Product_ID item is Purchased of top 15 Purchases'}, xlabel='Product_ID'>

# %%
sns.countplot(x = "Product_ID", data = df["Product_ID"].sort_values(ascending = False).head(15), hue = "Gender")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-195-1b9f08f70a48> in <cell line: 1>()
# ----> 1 sns.countplot(x = "Product_ID", data = df["Product_ID"].sort_values(ascending = False).head(15), hue = "Gender")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628         raise TypeError("Cannot pass values for both `x` and `y`.")
#    2629
# -> 2630     p = _CategoricalAggPlotter(
#    2631         data=data,
#    2632         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ...

# %%
df["Purchase"].head(15).plot(kind = "bar")
# Out:
# <Axes: >

# %%
df.loc[:,["Product_ID", "Purchase"]].sort_values(by = "Purchase", ascending = False).set_index("Product_ID")["Purchase"].head(15).plot(kind = "bar",title = "Highest amount Purchased Product_ID")
# Out:
# <Axes: title={'center': 'Highest amount Purchased Product_ID'}, xlabel='Product_ID'>

# %%
df.loc[:,["Product_ID", "Purchase"]].sort_values(by = "Purchase", ascending = False).set_index("Product_ID")
# Out:
#             Purchase
# Product_ID
# P00052842      23961
# P00052842      23961
# P00052842      23961
# P00119342      23960
# P00117642      23960
# ...              ...
# P00041442        186
# P00171342        185
# P00041442        185
# P00102142        185
# P00041442        185
#
# [537577 rows x 1 columns]

# %%
df["Product_ID"]
# Out:
# 0         P00069042
# 1         P00248942
# 2         P00087842
# 3         P00085442
# 4         P00285442
#             ...
# 537572    P00193542
# 537573    P00111142
# 537574    P00345942
# 537575    P00285842
# 537576    P00118242
# Name: Product_ID, Length: 537577, dtype: object

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200

# %%
lst = []
for i in range(len(df)):
    lst.append(df["Gender"][i] + "_" + str(df["Marital_Status"][i]))

# %%
df["Marital_Gender"] = pd.Series(lst)

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
df.groupby("Marital_Gender").count()
# Out:
#                 User_ID  Product_ID  Gender     Age  Occupation  \
# Marital_Gender
# F_0               76974       76974   76974   76974       76974
# F_1               55223       55223   55223   55223       55223
# M_0              240843      240843  240843  240843      240843
# M_1              164537      164537  164537  164537      164537
#
#                 City_Category  Stay_In_Current_City_Years  Marital_Status  \
# Marital_Gender
# F_0                     76974                       76974           76974
# F_1                     55223                       55223           55223
# M_0                    240843                      240843          240843
# M_1                    164537                      164537          164537
#
#                 Product_Category_1  Purchase
# Marital_Gender
# F_0                          76974     76974
# F_1                          55223     55223
# M_0                         240843    240843
# ...

# %%
sns.countplot(x=df["Marital_Gender"])
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>

# %%
sns.countplot(x = "Marital_Gender", hue = "Age", data = df)
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>

# %%
sns.countplot(x = "Marital_Gender", hue = "Stay_In_Current_City_Years", data = df)
# Out:
# <Axes: xlabel='Marital_Gender', ylabel='count'>
